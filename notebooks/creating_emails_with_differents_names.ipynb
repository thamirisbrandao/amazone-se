# %%
import pandas as pd

# %%
tabela = pd.read_excel('../raw_data/voluntarios.xlsx')
tabela
# Out:
#                                      LEGENDA: Membros do Intitucional  \
# 0             P.S Verificar Notas nas células                     NaN
# 1                               Nome completo      Data de Nascimento
# 2                 Adriana Bernardes Valentini     1969-01-02 00:00:00
# 3                 Adriana Bernardes Valentini     1969-01-02 00:00:00
# 4                Adriano Coutinho de Carvalho               5/19/1982
# 5                                  Aline Vick     1991-02-05 00:00:00
# 6               Barbara Cristina Da Luz Silva              12/26/1988
# 7                       Beatriz Bessa Marinho               5/13/2000
# 8                          Beatriz r s vieira               9/28/1990
# 9                            Carliane Moreira     2021-08-04 00:00:00
# 10                     Carolina Bozza Matheus     1993-08-10 00:00:00
# 11                  Carolina Pimentel Machado     1984-06-11 00:00:00
# ...

# %%
for nome in range(3, len(tabela['LEGENDA:'])):
    text_file = open(f"{nome}.txt", "w")
    text_file.write(f"""
    Oi, {tabela['LEGENDA:'][nome]} :)
    O projeto Amazone-se vai trazer um pouco do SENTIR da Floresta, numa experiência para RESGATAR nossa ancestralidade e [re]integrar o eu ao todo.
    Você irá vivenciar o ritual Amazone-se, no ritmo do Carimbó e com sabor dos peixes e frutas trazidas diretos do Pará.
    Vamos juntos viver essa energia da floresta E ainda ajudar a continuar nosso trabalho nas comunidades!!
    Data: 05/06/22, às 11:00h
    Onde: Rua Horácio Lane, 95 - Pinheiros - SP
    
    tabela['Voluntários Iniciantes ou Inativos']
    """)
    text_file.close()
    
    #' Após nossa participação no programa do Caldeirão do Huck conseguimos arrecadar x e realizamos 3 vivências de saúde. Agora estamos precisando levantar fundo para realizar as próximas vivências. Nossa maneira Amazone-se de unir forças foi trazer um pouco do SENTIR da Floresta. Uma experiência para RESGATAR nossa ancestralidade e [r]eintegrar o eu ao todo. Você irá vivenciar o ritual Amazone-se, no ritmo do Carimbó e com sabor dos peixes e frutas trazidas diretos do Pará. Você precisa viver isso com a gente. Data: 05/06/22 11:30h Onde: Base Colaborativa'
